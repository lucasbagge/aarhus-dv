# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1.0, 7.0, 100)
y = (2*np.sin(x))/(1 + x**2)
fig, ax = plt.subplots()
ax.plot(x,y)
plt.show()

# %% [markdown]
# ## opgave 2.4
#
# Hvilket udtryk mener du python vil beregn mest korrekt?
#
# Jeg vil mene det er den kontraderede udtryk.

# %% [markdown]
# ## Opgave 2.5
# ![alt text](2.5.png "2.5")
#
# - Løsning kan findes i IMO noter hvor vi har brugt association regler.

# %% [markdown]
# ## Opgave 2.6
#
# ![alt text](2.6.png)
